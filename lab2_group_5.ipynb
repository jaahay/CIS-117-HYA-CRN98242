# %% [markdown]
# #Lab 2
# - Write the code for each one of the tests
# - Make sure to leave the outputs under the code cells after you run them
# - Turn in both files: this notebook and the Antics.py module
#
# **Authors first and last name**:
# - James Hay
#
# **2025-09-25**

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ## Setup
# Copy Antics.py to the same folder where you have this notebook and run the following two cells to do the setup.

# %%
# Run this cell to mount your Google Drive
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/gdrive', force_remount=True)
# %cd /content/gdrive/MyDrive/Colab Notebooks
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Colab Notebooks

# %%
import importlib

# Before you run this cell, make sure you have Antics.py inside the Colab Notebooks folder
import Antics as ant

# print("Notebook is alive!")

# %% [markdown]
# # Directions for Testing
# Write test cases for tests 1-6.
# Note that I give you an example on how to write the test case on the first test. You are expected to follow the same format on all tests.
#
# Leave the outputs on each task.

# %% [markdown]
# **Test 1:** Use the following cell to test the palindrome function that you created in antics.py passing a word that is a palindrome and a word that is not a palindrome like in the example below.
#
# **palindrome:** a word or sentence that reads the same backwards
#
# An example is provided below. Change it to use your name instead of mine

# %%
importlib.reload(ant)

palindrome_examples = (
    "Anna", "Bob", "kayak", "deed", "rotator",
    "James",
    "anna"
)

for example in palindrome_examples:
  print(example, "is" if ant.palindrome(example) else "is not", "a palindrome")
# Out:
# Anna is a palindrome
# Bob is a palindrome
# kayak is a palindrome
# deed is a palindrome
# rotator is a palindrome
# James is not a palindrome
# anna is a palindrome

# %% [markdown]
# **Test 2:** Use the following cell to test the **pangram** function that you defined in antics.py passing a sentence that is a pangram and a sentence that is not a pangram
#
# **pangram:** a phrase or sentence containing all 26 letters of the alphabet
#
# *Example of a pangram sentence: The quick brown fox jumps over the lazy dog*
#
# Make sure to leave the output of your testing below the code cell

# %%
importlib.reload(ant)

pangram_examples = (
    "The quick brown fox jumps over the lazy dog.",
    "Mr. Jock, TV quiz Ph. D., bags few lynx.",
    "Movies are best enjoyed with pop-corn."
)

for example in pangram_examples:
  print("\"" + example + "\"\n\t", "is" if ant.pangram(example) else "is not", "a pangram")
# Out:
# "The quick brown fox jumps over the lazy dog."
# 	 is a pangram
# "Mr. Jock, TV quiz Ph. D., bags few lynx."
# 	 is a pangram
# "Movies are best enjoyed with pop-corn."
# 	 is not a pangram

# %% [markdown]
# **Test 3:** Use the following cell to test the **tautogram** function that you defined in antics.py passing a text that is a tautogram and a text that is not a tautogram
#
# **tautogram:** a text in which all words start with the same letter
#
# *Example of a tautogram sentence: Brilliant, because bacon bites beat bruschetta*
#
# Make sure to leave the output of your testing below the code cell

# %%
importlib.reload(ant)

tautogram_examples = (
    "Brilliant, because bacon bites beat bruschetta.",
    "Truly they triumph, trumpeting trills to trounce the terrible travesties.",
    "I inflame inactive ire instantly into infuriating internal infernos, igniting intense incendiary intent.",
    "When you wish upon a star."
)

for example in tautogram_examples:
  print("\"" + example + "\"\n\t", "is" if ant.tautogram(example) else "is not", "a tautogram")
# Out:
# "Brilliant, because bacon bites beat bruschetta."
# 	 is a tautogram
# "Truly they triumph, trumpeting trills to trounce the terrible travesties."
# 	 is a tautogram
# "I inflame inactive ire instantly into infuriating internal infernos, igniting intense incendiary intent."
# 	 is a tautogram
# "When you wish upon a star."
# 	 is not a tautogram

# %% [markdown]
# **Test 4:** Use the following cell to test the **isogram** function that you defined in antics.py passing a word that is an isogram and a word that is not an isoogram
#
# **isogram:** a word in which no letter of the alphabet occurs more than once
#
# *Example of an isogram: demographics*
#
# Make sure to leave the output of your testing below the code cell

# %%
importlib.reload(ant)

isogram_examples = (
    "demographics",
    "school",
    "everything",
    "course",
    "computers",
    "background",
    "uncopyrightable",
    "lumberjacks",
)

for example in isogram_examples:
  print(example, "is" if ant.isogram(example) else "is not", "an isogram")
# Out:
# demographics is an isogram
# school is not an isogram
# everything is not an isogram
# course is an isogram
# computers is an isogram
# background is an isogram
# uncopyrightable is an isogram
# lumberjacks is an isogram

# %% [markdown]
# **Test 5:** Use this cell to test the **abecedarian** function that you defined in antics.py passing a word that is an abecedarian and a word that is not an abecedarian
#
# **abecedarian:** a word in which the letters appear in alphabetical order
#
# *Examples of abecedarian words: bijoux, biopsy, dimpsy*
#
# Make sure to leave the output of your testing below the code cell

# %%
importlib.reload(ant)

abecedarian_examples = (
    "bijoux", "biopsy", "dimpsy",
    "necklace",
    "biology",
    "dotty"
)

for example in abecedarian_examples:
  print(example, "is" if ant.abecedarian(example) else "is not", "an abecedarian")
# Out:
# bijoux is an abecedarian
# biopsy is an abecedarian
# dimpsy is an abecedarian
# necklace is not an abecedarian
# biology is not an abecedarian
# dotty is an abecedarian

# %% [markdown]
# **Test 6:** Use the following cell to test the **dobloon** function that you defined in antis.py passing a word that is a dobloon and a word that is not a dobloon
#
# **dobloon:** a word in which every letter that appears in the word appears exactly twice
#
# *Examples of dobloons: murmur, noon, reappear, sees*
#
# Make sure to leave the output of your testing below the code cell

# %%
importlib.reload(ant)

dobloon_examples = (
    "murmur", "noon", "reappear", "sees",
    "aardvark",
    "bicentennial",
    "courage"
)

for example in dobloon_examples:
  print(example, "is" if ant.dobloon(example) else "is not", "a dobloon")
# Out:
# murmur is a dobloon
# noon is a dobloon
# reappear is a dobloon
# sees is a dobloon
# aardvark is not a dobloon
# bicentennial is not a dobloon
# courage is not a dobloon

# %% [markdown]
# # Submission instructions
# Make sure you have your name in the first cell.
#
# After testing all the functions you implemented in Antics.py, share the link to this notebook on Canvas. Make sure to leave all outputs.
#
# Also upload the Antics.py that you completed with your partner
